# %% [markdown]
# # **Dice Score Evaluation** - self implemented kmeans vs. Cellpose Deep Learning on Yeast Cells and Cell Nuclei Images
#
# # Created ground Truth with Cellpose (Stringer et al., 2021) durchgeführt
#
# Reference:
# Stringer, C., Wang, T., Michaelos, M., & Pachitariu, M. (2021). Cellpose: a generalist algorithm for cellular segmentation. Nature Methods, 18(1), 100-106.

# %%
#Dice Score Cell Nuclei: self implemented kmeans vs. Cellpose Deep Learning model

from Functions.Dice_coefficient_correct_loading import evaluate_and_plot_dice_cells

image_pairs = [
    ('Images/Segmented_Images/SegIntoTwoClusters/RGB_segmented_images/clustered_RGB_norm_CellNuclei_GB.png',
     '/Users/davidlehmann/Downloads/Cell_Nuclei_Cellpose_BlueChannel.png'),
     
]

evaluate_and_plot_dice_cells(image_pairs)
# Out:
#                                    Bild  DiceScore
# 0  clustered_RGB_norm_CellNuclei_GB.png   0.959732

# %%
#Dice Score Yeast Cells: self implemented kmeans vs. Cellpose Deep Learning model


from Functions.Dice_coefficient_correct_loading import evaluate_and_plot_dice_cells

image_pairs = [
    ('Images/Segmented_Images/SegIntoTwoClusters/RGB_segmented_images/clustered_RGB_norm_YeastCells.png',
     '/Users/davidlehmann/Downloads/Yeast_Cells_Cellpose.png'),
     ('Images/Segmented_Images/SegIntoTwoClusters/HSV_segmented_images/clustered_HSV_norm_YeastCells.png',
     '/Users/davidlehmann/Downloads/Yeast_Cells_Cellpose.png'),
     ('Images/Segmented_Images/SegIntoTwoClusters/HSV_segmented_images/clustered_HSV_norm_YeastCells_Value.png',
     '/Users/davidlehmann/Downloads/Yeast_Cells_Cellpose.png'),
     ('Images/Segmented_Images/SegIntoTwoClusters/HSV_segmented_images/clustered_HSV_norm_YeastCells_Hue.png',
     '/Users/davidlehmann/Downloads/Yeast_Cells_Cellpose.png'),

]

evaluate_and_plot_dice_cells(image_pairs)
# Out:
#                                       Bild  DiceScore
# 0        clustered_RGB_norm_YeastCells.png   0.934588
# 1        clustered_HSV_norm_YeastCells.png   0.938385
# 2  clustered_HSV_norm_YeastCells_Value.png   0.915846
# 3    clustered_HSV_norm_YeastCells_Hue.png   0.492105

# %% [markdown]
# # **Dice Score Evaluation** - self implemented kmeans vs. sk learn kmeans on Yeast Cells and Cell Nuclei Images

# %%
from Functions.Dice_coefficient_correct_loading import evaluate_and_plot_dice_cells


image_pairs = [
    ('Images/Segmented_Images/SegIntoTwoClusters/RGB_segmented_images/clustered_RGB_norm_CellNuclei_GB.png',
     'Images/sklearn_segmented_images/Cell_Nuclei_sk_learn/CellNuclei_GB_skclustered.tiff'),
    ('Images/Segmented_Images/SegIntoTwoClusters/RGB_segmented_images/clustered_RGB_norm_YeastCells.png',
     'Images/sklearn_segmented_images/Yeast_Cells_sk_learn /Yeast_Cells_skclustered_Original.tiff'),

]

evaluate_and_plot_dice_cells(image_pairs)
# Out:
# Datei nicht gefunden: [Errno 2] No such file or directory: 'Images/sklearn_segmented_images/Yeast_Cells_sk_learn /Yeast_Cells_skclustered_Original.tiff'
#                                    Bild  DiceScore
# 0  clustered_RGB_norm_CellNuclei_GB.png        1.0

# %% [markdown]
# # **Dice Score Evaluation:** Is the bilateral filter or the gauß filter better?

# %%
from Functions.Dice_coefficient_correct_loading import evaluate_and_plot_dice_cells

image_pairs = [
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t13.tiff',
     'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),

    ('Images/Datenvorbereitung_Images/Otsu/Otsu_Filtered_t13/Otsu_t13_bilateral.tiff',
     'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),

    ('Images/Datenvorbereitung_Images/Otsu/Otsu_Filtered_t13/Otsu_t13_gauß.tiff',
     'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),

    ('Images/Segmented_Images/t13_for_filterevaluation/clustered_gray_t13_bilateral_norm.png',
     'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),

    ('Images/Segmented_Images/t13_for_filterevaluation/clustered_gray_t13_gauß_norm.png',
     'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),

    ('Images/Segmented_Images/t13_for_filterevaluation/clustered_gray_t13_norm.png',
     'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),

    ('Images/Segmented_Images/t13_for_filterevaluation/clustered_gray_t13_median(kernel3)_norm.png',
     'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),

    ('Images/Segmented_Images/t13_for_filterevaluation/clustered_gray_t13_median(kernel5)_norm.png',
     'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),


]

evaluate_and_plot_dice_cells(image_pairs)
# Out:
#                                           Bild  DiceScore
# 0                                Otsu_t13.tiff   0.662428
# 1                      Otsu_t13_bilateral.tiff   0.640193
# 2                           Otsu_t13_gauß.tiff   0.554454
# 3        clustered_gray_t13_bilateral_norm.png   0.640193
# 4             clustered_gray_t13_gauß_norm.png   0.554454
# 5                  clustered_gray_t13_norm.png   0.685589
# 6  clustered_gray_t13_median(kernel3)_norm.png   0.685444
# 7  clustered_gray_t13_median(kernel5)_norm.png   0.683403

# %% [markdown]
# # **Dice Score Evaluation Bar Plot** - self implemented kmeans vs. Otsu vs. Ground Truth on N2DL-HeLa dataset

# %%
from Functions.Dice_coefficient_correct_loading import evaluate_and_plot_dice_cells
import pandas as pd

otsu_pairs = [
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t13.tiff', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t52.tiff', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg52.tif'),
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t75.tiff', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg75.tif'),
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t79.tiff', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg79.tif'),
]

kmeans_pairs = [
    ('Images/Segmented_Images/SegIntoTwoClusters/grayscale_segmented_images/clustered_gray_norm_t13.png', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),
    ('Images/Segmented_Images/SegIntoTwoClusters/grayscale_segmented_images/clustered_gray_norm_t52.png', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg52.tif'),
    ('Images/Segmented_Images/SegIntoTwoClusters/grayscale_segmented_images/clustered_gray_norm_t75.png', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg75.tif'),
    ('Images/Segmented_Images/SegIntoTwoClusters/grayscale_segmented_images/clustered_gray_norm_t79.png', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg79.tif'),
]

df_otsu = evaluate_and_plot_dice_cells(otsu_pairs)
df_kmeans = evaluate_and_plot_dice_cells(kmeans_pairs)

combined_df = pd.concat([df_otsu, df_kmeans], ignore_index=True)
print(combined_df)
# Out:
#                           Bild  DiceScore
# 0                Otsu_t13.tiff   0.662428
# 1                Otsu_t52.tiff   0.532174
# 2                Otsu_t75.tiff   0.752987
# 3                Otsu_t79.tiff   0.759848
# 4  clustered_gray_norm_t13.png   0.685589
# 5  clustered_gray_norm_t52.png   0.647869
# 6  clustered_gray_norm_t75.png   0.769186
# 7  clustered_gray_norm_t79.png   0.766018

# %% [markdown]
# # **Dice Score Evaluation Lineplot** - self implemented kmeans vs. Otsu vs. Ground Truth on N2DL-HeLa dataset

# %%
from Functions.Dice_coefficient_correct_loading import evaluate_segmentation_line

otsu_pairs = [
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t13.tiff', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t52.tiff', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg52.tif'),
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t75.tiff', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg75.tif'),
    ('Images/Datenvorbereitung_Images/Otsu/Otus_Original/Otsu_t79.tiff', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg79.tif'),
]

kmeans_pairs = [
    ('Images/Segmented_Images/SegIntoTwoClusters/grayscale_segmented_images/clustered_gray_norm_t13.png', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg13.tif'),
    ('Images/Segmented_Images/SegIntoTwoClusters/grayscale_segmented_images/clustered_gray_norm_t52.png', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg52.tif'),
    ('Images/Segmented_Images/SegIntoTwoClusters/grayscale_segmented_images/clustered_gray_norm_t75.png', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg75.tif'),
    ('Images/Segmented_Images/SegIntoTwoClusters/grayscale_segmented_images/clustered_gray_norm_t79.png', 'Original_Images/Otsu/Data/N2DL-HeLa/gt/man_seg79.tif'),
]

df_results = evaluate_segmentation_line(otsu_pairs, kmeans_pairs)
